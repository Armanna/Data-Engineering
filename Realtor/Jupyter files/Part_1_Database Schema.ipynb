# %% [markdown]
# # <span style="color:red">REALTOR Database Schema</span>

# %% [markdown]
# ![Schema.jpg](attachment:Schema.jpg)

# %% [markdown]
# # <span style="color:red">Tables</span>

# %% [markdown]
# # Provinces
# - province_id              <span style="color:red">(PK)</span>
# - name
#
#
# # City
# - city_id                  <span style="color:red">(PK)</span>
# - name
# - population
# - area
# - province_id              <span style="color:red">(FK)</span>
#
# # Property_type
# - property_type_id         <span style="color:red">(PK)</span>
# - name
#
# # Building_type
# - building_type_id         <span style="color:red">(PK)</span>
# - name
#
# # Property_ownership_type
# - property_ownership_id    <span style="color:red">(PK)</span>
# - name
#
# # Estate_status
# - estate_status_id         <span style="color:red">(PK)</span>
# - status
#
# # Estate
# - estate_id                <span style="color:red">(PK)</span>
# - province_id              <span style="color:red">(FK)</span>
# - city_id                  <span style="color:red">(FK)</span>
# - address
# - property_postal_code
# - property_type_id         <span style="color:red">(FK)</span>
# - building_type_id         <span style="color:red">(FK)</span>
# - storeys
# - interior_size
# - bedrooms
# - bathrooms
# - price
# - description
# - property_ownership_type
# - estate_status_id         <span style="color:red">(FK)</span>
#
#
#
# # Organization
# - organization_id          <span style="color:red">(PK)</span>
# - name
# - address
# - phone_area_code
# - phone_number
# - fax_area_code
# - fax_number
#
# # Position
# - position_id               <span style="color:red">(PK)</span>
# - name
#
# # Broker
# - position_id               <span style="color:red">(PK)</span>
# - first_name
# - last_name
# - organization_id           <span style="color:red">(FK)</span>
# - position_id               <span style="color:red">(FK)</span>
# - area_code
# - phone_number
#
# # Job
# - job_id                    <span style="color:red">(PK)</span>
# - name
# - wages (dollar/hour)
#
# # Buyer
# - buyer_id                  <span style="color:red">(PK)</span>
# - first_name
# - last_name
# - age
# - city_id                   <span style="color:red">(FK)</span>
# - marital_status_id         <span style="color:red">(FK)</span>
# - job_id                    <span style="color:red">(FK)</span>
# - area_code
# - phone_number
#
# # Marital_status
# - marital_status_id         <span style="color:red">(PK)</span>
# - status
#
# # Owner
# - owner_id                  <span style="color:red">(PK)</span>
# - first_name
# - last_name
# - city_id                   <span style="color:red">(FK)</span>
# - area_code
# - phone_number
#
# # Relationship_result
# - relationship_result_id     <span style="color:red">(PK)</span>
# - name
#
# # Estate_Broker_Relationship
# - estate_id                  <span style="color:red">(FK)(1-1)</span>
# - broker_id                  <span style="color:red">(FK)</span>
# - result_id                  <span style="color:red">(FK)</span>
#
#
# # Broker_behavior
# - broker_id                  <span style="color:red">(FK)(1-1)</span>
# - estates_in_touch
# - estates_succeeded
# - estates_failed
#
# # Contract
# - contract_id                <span style="color:red">(PK)</span>
# - estate_id                  <span style="color:red">(FK)</span>
# - broker_id                  <span style="color:red">(FK)</span>
# - buyer_id                   <span style="color:red">(FK)</span>
# - owner_id                   <span style="color:red">(FK)</span>
# - date
# - price

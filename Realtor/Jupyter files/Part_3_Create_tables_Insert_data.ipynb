# %% [markdown]
# # Import libraries

# %%
import pandas as pd

# %% [markdown]
# # The main scraped table

# %%
# From Project_1

# %%
main_table = pd.read_csv(r'C:\Users\dell\Dropbox\My PC (DESKTOP-LL2SGK9)\Desktop\Data Engineering ACA\Project\Tables\main_data.csv')

# %%
main_table
# Out:
#        province        city    building_type  bathrooms bedrooms  storeys  \
# 0       Alberta     Airdrie            House        2.0    2 + 2      NaN
# 1       Alberta     Airdrie            House        3.0    3 + 0      2.0
# 2       Alberta     Airdrie            House        4.0    3 + 1      2.0
# 3       Alberta     Airdrie            House        3.0    3 + 3      NaN
# 4       Alberta     Airdrie  Row / Townhouse        1.0    2 + 0      1.0
# ...         ...         ...              ...        ...      ...      ...
# 123073    Yukon  Whitehorse        Apartment        1.0        0      NaN
# 123074    Yukon  Whitehorse  Row / Townhouse        3.0        3      NaN
# 123075    Yukon  Whitehorse  Row / Townhouse        3.0        3      NaN
# 123076    Yukon  Whitehorse  Row / Townhouse        3.0        3      NaN
# 123077    Yukon  Whitehorse              NaN        NaN      NaN      NaN
#
#        broker_first_name broker_last_name  broker_area_code  \
# ...

# %%
main_table.head()
# Out:
#   province     city    building_type  bathrooms bedrooms  storeys  \
# 0  Alberta  Airdrie            House        2.0    2 + 2      NaN
# 1  Alberta  Airdrie            House        3.0    3 + 0      2.0
# 2  Alberta  Airdrie            House        4.0    3 + 1      2.0
# 3  Alberta  Airdrie            House        3.0    3 + 3      NaN
# 4  Alberta  Airdrie  Row / Townhouse        1.0    2 + 0      1.0
#
#   broker_first_name broker_last_name  broker_area_code broker_phone_number  \
# 0            Farrah            Khoja             403.0            923-9445
# 1             Erick         Dillmann             403.0            828-1120
# 2              Anna             Pitt             403.0            605-7073
# 3             Glenn           Heslop             403.0            826-5693
# 4              Ryan            Smith             403.0            700-9737
#
#    ... property_postal_code  \
# 0  ...               T4B1K9
# 1  ...               T3P0W9
# ...

# %%
data = main_table

# %%
data.head()
# Out:
#   province     city    building_type  bathrooms bedrooms  storeys  \
# 0  Alberta  Airdrie            House        2.0    2 + 2      NaN
# 1  Alberta  Airdrie            House        3.0    3 + 0      2.0
# 2  Alberta  Airdrie            House        4.0    3 + 1      2.0
# 3  Alberta  Airdrie            House        3.0    3 + 3      NaN
# 4  Alberta  Airdrie  Row / Townhouse        1.0    2 + 0      1.0
#
#   broker_first_name broker_last_name  broker_area_code broker_phone_number  \
# 0            Farrah            Khoja             403.0            923-9445
# 1             Erick         Dillmann             403.0            828-1120
# 2              Anna             Pitt             403.0            605-7073
# 3             Glenn           Heslop             403.0            826-5693
# 4              Ryan            Smith             403.0            700-9737
#
#    ... property_postal_code  \
# 0  ...               T4B1K9
# 1  ...               T3P0W9
# ...

# %%
data = data.drop_duplicates()

# %%
data
# Out:
#        province        city    building_type  bathrooms bedrooms  storeys  \
# 0       Alberta     Airdrie            House        2.0    2 + 2      NaN
# 1       Alberta     Airdrie            House        3.0    3 + 0      2.0
# 2       Alberta     Airdrie            House        4.0    3 + 1      2.0
# 3       Alberta     Airdrie            House        3.0    3 + 3      NaN
# 4       Alberta     Airdrie  Row / Townhouse        1.0    2 + 0      1.0
# ...         ...         ...              ...        ...      ...      ...
# 123072    Yukon  Whitehorse        Apartment        1.0        0      NaN
# 123074    Yukon  Whitehorse  Row / Townhouse        3.0        3      NaN
# 123075    Yukon  Whitehorse  Row / Townhouse        3.0        3      NaN
# 123076    Yukon  Whitehorse  Row / Townhouse        3.0        3      NaN
# 123077    Yukon  Whitehorse              NaN        NaN      NaN      NaN
#
#        broker_first_name broker_last_name  broker_area_code  \
# ...

# %%
data = data.reset_index()

# %%
data
# Out:
#          index province        city    building_type  bathrooms bedrooms  \
# 0            0  Alberta     Airdrie            House        2.0    2 + 2
# 1            1  Alberta     Airdrie            House        3.0    3 + 0
# 2            2  Alberta     Airdrie            House        4.0    3 + 1
# 3            3  Alberta     Airdrie            House        3.0    3 + 3
# 4            4  Alberta     Airdrie  Row / Townhouse        1.0    2 + 0
# ...        ...      ...         ...              ...        ...      ...
# 118613  123072    Yukon  Whitehorse        Apartment        1.0        0
# 118614  123074    Yukon  Whitehorse  Row / Townhouse        3.0        3
# 118615  123075    Yukon  Whitehorse  Row / Townhouse        3.0        3
# 118616  123076    Yukon  Whitehorse  Row / Townhouse        3.0        3
# 118617  123077    Yukon  Whitehorse              NaN        NaN      NaN
#
#         storeys broker_first_name broker_last_name  broker_area_code  ...  \
# ...

# %%
del data['index']

# %%
data
# Out:
#        province        city    building_type  bathrooms bedrooms  storeys  \
# 0       Alberta     Airdrie            House        2.0    2 + 2      NaN
# 1       Alberta     Airdrie            House        3.0    3 + 0      2.0
# 2       Alberta     Airdrie            House        4.0    3 + 1      2.0
# 3       Alberta     Airdrie            House        3.0    3 + 3      NaN
# 4       Alberta     Airdrie  Row / Townhouse        1.0    2 + 0      1.0
# ...         ...         ...              ...        ...      ...      ...
# 118613    Yukon  Whitehorse        Apartment        1.0        0      NaN
# 118614    Yukon  Whitehorse  Row / Townhouse        3.0        3      NaN
# 118615    Yukon  Whitehorse  Row / Townhouse        3.0        3      NaN
# 118616    Yukon  Whitehorse  Row / Townhouse        3.0        3      NaN
# 118617    Yukon  Whitehorse              NaN        NaN      NaN      NaN
#
#        broker_first_name broker_last_name  broker_area_code  \
# ...

# %%
for i in data:
    print(i, "-", data[i].unique())
    print(len(data[i].unique()))
    print("________________________________________________________________________________")
# Out:
# province - ['Alberta' 'British Columbia' 'Manitoba' 'New Brunswick'
#  'Newfoundland and Labrador' 'Northwest Territories' 'Nova Scotia'
#  'Ontario' 'Prince Edward Island' 'Quebec' 'Saskatchewan' 'Yukon']
# 12
# ________________________________________________________________________________
# city - ['Airdrie' 'Beaumont' 'Brooks' 'Calgary' 'Camrose' 'Chestermere'
#  'Cold Lake' 'Edmonton' 'Fort Saskatchewan' 'Grande Prairie' 'Lacombe'
#  'Leduc' 'Lethbridge' 'Lloydminster ' 'Medicine Hat' 'Red Deer'
#  'Spruce Grove' 'St. Albert' 'Wetaskiwin' 'Abbotsford' 'Armstrong'
#  'Burnaby' 'Campbell River' 'Castlegar' 'Chilliwack' 'Colwood' 'Coquitlam'
#  'Courtenay' 'Cranbrook' 'Dawson Creek' 'Delta' 'Duncan' 'Enderby'
#  'Fernie' 'Fort St. John' 'Grand Forks' 'Greenwood' 'Kamloops' 'Kelowna'
#  'Kimberley' 'Langford' 'Langley' 'Maple Ridge' 'Merritt' 'Mission'
#  'Nanaimo' 'Nelson' 'New Westminster' 'North Vancouver' 'Parksville'
# ...

# %%
data[data['property_type']=='Recreational']
# Out:
#                     province                 city building_type  bathrooms  \
# 8138        British Columbia       Campbell River           NaN        2.0
# 8176        British Columbia       Campbell River           NaN        0.0
# 8248        British Columbia       Campbell River           NaN        1.0
# 11573       British Columbia             Kamloops  Recreational        NaN
# 11612       British Columbia             Kamloops   No Building        NaN
# ...                      ...                  ...           ...        ...
# 49210   Prince Edward Island  Charlottetown[PE 1]  Recreational        1.0
# 91161                 Quebec        Rouyn-Noranda   Mobile Home        0.0
# 109005                Quebec           Senneterre           NaN        0.0
# 111289                Quebec          Témiscaming           NaN        1.0
# 111325                Quebec          Témiscaming         Other        0.0
#
# ...

# %%
data = data[data.property_type != 'Vacant Land']

# %%
data = data[data.property_type != 'Agriculture']

# %%
data = data[data.property_type != 'Parking']

# %%
data = data[data.property_type != 'Other']
data = data[data.property_type != 'Office']

# %%
data
# Out:
#        province        city    building_type  bathrooms bedrooms  storeys  \
# 0       Alberta     Airdrie            House        2.0    2 + 2      NaN
# 1       Alberta     Airdrie            House        3.0    3 + 0      2.0
# 2       Alberta     Airdrie            House        4.0    3 + 1      2.0
# 3       Alberta     Airdrie            House        3.0    3 + 3      NaN
# 4       Alberta     Airdrie  Row / Townhouse        1.0    2 + 0      1.0
# ...         ...         ...              ...        ...      ...      ...
# 118612    Yukon  Whitehorse        Apartment        1.0        0      NaN
# 118613    Yukon  Whitehorse        Apartment        1.0        0      NaN
# 118614    Yukon  Whitehorse  Row / Townhouse        3.0        3      NaN
# 118615    Yukon  Whitehorse  Row / Townhouse        3.0        3      NaN
# 118616    Yukon  Whitehorse  Row / Townhouse        3.0        3      NaN
#
#        broker_first_name broker_last_name  broker_area_code  \
# ...

# %%
for i in data:
    print(i, "-", data[i].unique())
    print(len(data[i].unique()))
    print("________________________________________________________________________________")
# Out:
# province - ['Alberta' 'British Columbia' 'Manitoba' 'New Brunswick'
#  'Newfoundland and Labrador' 'Northwest Territories' 'Nova Scotia'
#  'Ontario' 'Prince Edward Island' 'Quebec' 'Saskatchewan' 'Yukon']
# 12
# ________________________________________________________________________________
# city - ['Airdrie' 'Beaumont' 'Brooks' 'Calgary' 'Camrose' 'Chestermere'
#  'Cold Lake' 'Edmonton' 'Fort Saskatchewan' 'Grande Prairie' 'Lacombe'
#  'Leduc' 'Lethbridge' 'Lloydminster ' 'Medicine Hat' 'Red Deer'
#  'Spruce Grove' 'St. Albert' 'Wetaskiwin' 'Abbotsford' 'Armstrong'
#  'Burnaby' 'Campbell River' 'Castlegar' 'Chilliwack' 'Colwood' 'Coquitlam'
#  'Courtenay' 'Cranbrook' 'Dawson Creek' 'Delta' 'Duncan' 'Enderby'
#  'Fernie' 'Fort St. John' 'Grand Forks' 'Greenwood' 'Kamloops' 'Kelowna'
#  'Kimberley' 'Langford' 'Langley' 'Maple Ridge' 'Merritt' 'Mission'
#  'Nanaimo' 'Nelson' 'New Westminster' 'North Vancouver' 'Parksville'
# ...

# %%
del data_1

# %%
data
# Out:
#        province        city    building_type  bathrooms bedrooms  storeys  \
# 0       Alberta     Airdrie            House        2.0    2 + 2      NaN
# 1       Alberta     Airdrie            House        3.0    3 + 0      2.0
# 2       Alberta     Airdrie            House        4.0    3 + 1      2.0
# 3       Alberta     Airdrie            House        3.0    3 + 3      NaN
# 4       Alberta     Airdrie  Row / Townhouse        1.0    2 + 0      1.0
# ...         ...         ...              ...        ...      ...      ...
# 118612    Yukon  Whitehorse        Apartment        1.0        0      NaN
# 118613    Yukon  Whitehorse        Apartment        1.0        0      NaN
# 118614    Yukon  Whitehorse  Row / Townhouse        3.0        3      NaN
# 118615    Yukon  Whitehorse  Row / Townhouse        3.0        3      NaN
# 118616    Yukon  Whitehorse  Row / Townhouse        3.0        3      NaN
#
#        broker_first_name broker_last_name  broker_area_code  \
# ...

# %%
data['storeys'] = data['storeys'].fillna(1)

# %%
data
# Out:
#        province        city    building_type  bathrooms bedrooms  storeys  \
# 0       Alberta     Airdrie            House        2.0    2 + 2      1.0
# 1       Alberta     Airdrie            House        3.0    3 + 0      2.0
# 2       Alberta     Airdrie            House        4.0    3 + 1      2.0
# 3       Alberta     Airdrie            House        3.0    3 + 3      1.0
# 4       Alberta     Airdrie  Row / Townhouse        1.0    2 + 0      1.0
# ...         ...         ...              ...        ...      ...      ...
# 118612    Yukon  Whitehorse        Apartment        1.0        0      1.0
# 118613    Yukon  Whitehorse        Apartment        1.0        0      1.0
# 118614    Yukon  Whitehorse  Row / Townhouse        3.0        3      1.0
# 118615    Yukon  Whitehorse  Row / Townhouse        3.0        3      1.0
# 118616    Yukon  Whitehorse  Row / Townhouse        3.0        3      1.0
#
#        broker_first_name broker_last_name  broker_area_code  \
# ...

# %%
data = data.drop('time_on_realtor', 1)

# %%
data.columns
# Out:
# Index(['province', 'city', 'building_type', 'bathrooms', 'bedrooms', 'storeys',
#        'broker_first_name', 'broker_last_name', 'broker_area_code',
#        'broker_phone_number', 'broker_position', 'organization_name',
#        'organization_address', 'organization_type',
#        'organization_phone_area_code', 'organization_phone_number',
#        'organization_fax_area_code', 'organization_fax_number',
#        'property_postal_code', 'property_address', 'property_ownership_type',
#        'parking_space_total', 'parking_type', 'price', 'property_type',
#        'interior_size', 'description'],
#       dtype='object')

# %%
data[data['description'].isna()]
# Out:
# Empty DataFrame
# Columns: [province, city, building_type, bathrooms, bedrooms, storeys, broker_first_name, broker_last_name, broker_area_code, broker_phone_number, broker_position, organization_name, organization_address, organization_type, organization_phone_area_code, organization_phone_number, organization_fax_area_code, organization_fax_number, property_postal_code, property_address, property_ownership_type, parking_space_total, parking_type, price, property_type, interior_size, description]
# Index: []
#
# [0 rows x 27 columns]

# %%
data[['province', 'city', 'building_type', 'bathrooms', 'bedrooms', 'storeys']]
# Out:
#        province        city    building_type  bathrooms bedrooms  storeys
# 0       Alberta     Airdrie            House        2.0    2 + 2      1.0
# 1       Alberta     Airdrie            House        3.0    3 + 0      2.0
# 2       Alberta     Airdrie            House        4.0    3 + 1      2.0
# 3       Alberta     Airdrie            House        3.0    3 + 3      1.0
# 4       Alberta     Airdrie  Row / Townhouse        1.0    2 + 0      1.0
# ...         ...         ...              ...        ...      ...      ...
# 118612    Yukon  Whitehorse        Apartment        1.0        0      1.0
# 118613    Yukon  Whitehorse        Apartment        1.0        0      1.0
# 118614    Yukon  Whitehorse  Row / Townhouse        3.0        3      1.0
# 118615    Yukon  Whitehorse  Row / Townhouse        3.0        3      1.0
# 118616    Yukon  Whitehorse  Row / Townhouse        3.0        3      1.0
#
# [101285 rows x 6 columns]

# %%
data['broker_position'] = data['broker_position'].fillna('Broker')

# %%
data['organization_phone_area_code'] = data['organization_phone_area_code'].fillna('No')

# %%
data['organization_phone_number'] = data['organization_phone_number'].fillna('No')

# %%
data['organization_fax_area_code'] = data['organization_fax_area_code'].fillna('No')

# %%
data['organization_fax_number'] = data['organization_fax_number'].fillna('No')

# %%
data['property_postal_code'] = data['property_postal_code'].fillna('No')

# %%
data['property_ownership_type'] = data['property_ownership_type'].fillna('Unknown')

# %%
data['parking_space_total'] = data['parking_space_total'].fillna('1')

# %%
data['parking_type'] = data['parking_type'].fillna('Garage')

# %%
data['interior_size'] = data['interior_size'].fillna('Unknown')

# %%
data
# Out:
#        province        city    building_type  bathrooms bedrooms  storeys  \
# 0       Alberta     Airdrie            House        2.0    2 + 2      1.0
# 1       Alberta     Airdrie            House        3.0    3 + 0      2.0
# 2       Alberta     Airdrie            House        4.0    3 + 1      2.0
# 3       Alberta     Airdrie            House        3.0    3 + 3      1.0
# 4       Alberta     Airdrie  Row / Townhouse        1.0    2 + 0      1.0
# ...         ...         ...              ...        ...      ...      ...
# 118612    Yukon  Whitehorse        Apartment        1.0        0      1.0
# 118613    Yukon  Whitehorse        Apartment        1.0        0      1.0
# 118614    Yukon  Whitehorse  Row / Townhouse        3.0        3      1.0
# 118615    Yukon  Whitehorse  Row / Townhouse        3.0        3      1.0
# 118616    Yukon  Whitehorse  Row / Townhouse        3.0        3      1.0
#
#        broker_first_name broker_last_name  broker_area_code  \
# ...

# %%
data = data.dropna()

# %%
data
# Out:
#        province        city    building_type  bathrooms bedrooms  storeys  \
# 0       Alberta     Airdrie            House        2.0    2 + 2      1.0
# 1       Alberta     Airdrie            House        3.0    3 + 0      2.0
# 2       Alberta     Airdrie            House        4.0    3 + 1      2.0
# 3       Alberta     Airdrie            House        3.0    3 + 3      1.0
# 4       Alberta     Airdrie  Row / Townhouse        1.0    2 + 0      1.0
# ...         ...         ...              ...        ...      ...      ...
# 118612    Yukon  Whitehorse        Apartment        1.0        0      1.0
# 118613    Yukon  Whitehorse        Apartment        1.0        0      1.0
# 118614    Yukon  Whitehorse  Row / Townhouse        3.0        3      1.0
# 118615    Yukon  Whitehorse  Row / Townhouse        3.0        3      1.0
# 118616    Yukon  Whitehorse  Row / Townhouse        3.0        3      1.0
#
#        broker_first_name broker_last_name  broker_area_code  \
# ...

# %%
data = data.reset_index()

# %%
data
# Out:
#         index province        city    building_type  bathrooms bedrooms  \
# 0           0  Alberta     Airdrie            House        2.0    2 + 2
# 1           1  Alberta     Airdrie            House        3.0    3 + 0
# 2           2  Alberta     Airdrie            House        4.0    3 + 1
# 3           3  Alberta     Airdrie            House        3.0    3 + 3
# 4           4  Alberta     Airdrie  Row / Townhouse        1.0    2 + 0
# ...       ...      ...         ...              ...        ...      ...
# 96530  118612    Yukon  Whitehorse        Apartment        1.0        0
# 96531  118613    Yukon  Whitehorse        Apartment        1.0        0
# 96532  118614    Yukon  Whitehorse  Row / Townhouse        3.0        3
# 96533  118615    Yukon  Whitehorse  Row / Townhouse        3.0        3
# 96534  118616    Yukon  Whitehorse  Row / Townhouse        3.0        3
#
#        storeys broker_first_name broker_last_name  broker_area_code  ...  \
# ...

# %%
data.to_csv('main_data_preprocessed.csv', index=False)
